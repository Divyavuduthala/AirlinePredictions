# %%
import pandas as pd
import numpy as np

atl = pd.read_csv('atl_data.csv')
atl.head()
# Out:
#    Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime UniqueCarrier  FlightNum  \
# 0      1          19          6    916.0         900            XE       1265
# 1      1          16          3   2102.0        1739            XE       2622
# 2      1          22          2    919.0         900            XE       2023
# 3      1           1          2   1127.0        1035            XE       1221
# 4      1           5          6   1733.0        1720            XE       2562
#
#    Distance Dest  Cancelled
# 0       745  ATL          0
# 1       689  ATL          0
# 2       554  ATL          0
# 3       745  ATL          0
# 4       689  ATL          0

# %%
cancelled = atl.loc[atl['Cancelled']==True]

# %%
rand = atl.sample(26)
rand
# Out:
#         Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime UniqueCarrier  \
# 60987       7          27          7   1831.0        1824            FL
# 90279      11          30          7    603.0         555            EV
# 48983       6          15          7   1921.0        1911            FL
# 95280      12          15          1   1824.0        1800            DL
# 104564     12          25          4   1844.0        1630            MQ
# 83383      10           8          3   2038.0        1941            FL
# 64960       8           7          4   2158.0        2130            UA
# 44940       6          29          7   1652.0        1645            DL
# 11744       2          24          7   1209.0        1159            EV
# 60536       7          22          2   1443.0        1430            FL
# 105905     12           5          5   1055.0        1045            DL
# 26816       3           4          2   1745.0        1605            DL
# ...

# %%
sample = cancelled.append(rand)
# sample.to_csv('atl_flight_sample.csv')
sample.set_index(np.arange(len(sample)))
# Out:
#     Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime UniqueCarrier  \
# 0      10          18          6   1304.0        1242            EV
# 1      10          19          7    103.0        1758            EV
# 2      10          25          6   1143.0        1000            9E
# 3      11          29          6   1755.0        1647            YV
# 4      11          30          7   2201.0        2135            DL
# 5      11          30          7    855.0         745            EV
# 6      11          14          5   2028.0        1635            EV
# 7      11          12          3    611.0         540            9E
# 8      11           7          5   1757.0        1725            9E
# 9      12          20          6   2153.0        2105            YV
# 10     12          28          7   1555.0        1045            OO
# 11     12          15          1    643.0         630            DL
# 12     12          17          3   1719.0        1450            DL
# ...
